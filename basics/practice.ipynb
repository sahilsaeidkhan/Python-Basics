# %%
name = input("Enter your name")
age = int(input("Enter your age"))
print(f"Hey {name},you are {age} years old")
# Out:
# Hey sahil ,you are 2 years old

# %%
x = 10 + 3 * 2 ** 2
print(x)
# Out:
# 22

# %% [markdown]
# Take a decimal number as input (like 45.78 ) and output its:
# integer part -
# 45
# •
# fractional part -
# .78

# %%
num = input("Enter decimal number")
parts = num.split(".")

print(f"Integer part is {parts[0]}")
print(f"Fractional part is {parts[1]}")
# Out:
# Integer part is 56
# Fractional part is 45

# %%
# Explanation:
# This code uses two loops to print pairs of numbers (1,1), (1,2), (2,1), and (2,2). Each pair combines a number from the first loop with a number from the second loop.
for i in range(1, 3):  
  for j in range(1, 3):  
   print(f"({i}, {j})")
# Out:
# (1, 1)
# (1, 2)
# (2, 1)
# (2, 2)
